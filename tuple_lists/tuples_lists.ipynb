# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# 2026-02-01 17:44:43.823615: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-01 17:44:46.142922: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# TensorFlow version: 2.20.0

# %%
mnist = tf.keras.datasets.mnist

(x_train, y)
