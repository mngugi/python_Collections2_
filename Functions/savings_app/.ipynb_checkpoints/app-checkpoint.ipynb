# %%
from preparations import typeNum

result = typeNum()

print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from preparations import typeNum
# ----> 3 result = typeNum()
#       5 print(result)
#
# File /var/home/sizma86/Documents/GitHub/python_Collections2_/Functions/savings_app/preparations.py:2, in typeNum()
#       1 def typeNum():
# ----> 2     i = int(raw_input("Enter Number: ")) * 2
#       3     return i
#
# NameError: name 'raw_input' is not defined
