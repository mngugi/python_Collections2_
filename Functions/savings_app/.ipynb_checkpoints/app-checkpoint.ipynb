# %%
from savings_calc import final

calculate_interest = final()

print(f'Total Sum with interest: {round(calculate_interest,2)}')
# Out:
# Enter Interest Rate:  0.17
# Enter Capital:  200000
# Enter number of years: 3
# Total Sum with interest: 320322.6
