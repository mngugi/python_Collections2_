# %%
from ds2.figs import drawlist

L = [0,1,6,9,8,7]
drawlist(L, 'list03')
# Out:
# <svg baseProfile="full" height="60" version="1.1" width="600" xmlns="http://www.w3.org/2000/svg" xmlns:ev="http://www.w3.org/2001/xml-events" xmlns:xlink="http://www.w3.org/1999/xlink"><defs /><path d="M5.000000 5.000000 L5.000000 5.000000 L22.000000 5.000000 L22.000000 35.000000 L5.000000 35.000000 Z" fill="#ffffff" stroke="#000000" stroke-width="2" /><text dominant-baseline="central" fill="#000000" font-family="monospace" font-size="24" font-weight="normal" stroke="#000000" text-anchor="middle" x="13.5" y="20.0">0</text><path d="M22.000000 5.000000 L22.000000 5.000000 L39.000000 5.000000 L39.000000 35.000000 L22.000000 35.000000 Z" fill="#ffffff" stroke="#000000" stroke-width="2" /><text dominant-baseline="central" fill="#000000" font-family="monospace" font-size="24" font-weight="normal" stroke="#000000" text-anchor="middle" x="30.5" y="20.0">1</text><path d="M39.000000 5.000000 L39.000000 5.000000 L56.000000 5.000000 L56.000000 35.000000 L39.000000 35.000000 Z" fill="#ffffff" stroke="#000000" stroke-width="2" /><text dominant-baseline="central" fill="#000000" font-family="monospace" font-size="24" font-weight="normal" stroke="#000000" text-anchor="middle" x="47.5" y="20.0">6</text><path d="M56.000000 5.000000 L56.000000 5.000000 L73.000000 5.000000 L73.000000 35.000000 L56.000000 35.000000 Z" fill="#ffffff" stroke="#000000" stroke-width="2" /><text dominant-baseline="central" fill="#000000" font-family="monospace" font-size="24" font-weight="normal" stroke="#000000" text-anchor="middle" x="64.5" y="20.0">9</text><path d="M73.000000 5.000000 L73.000000 5.000000 L90.000000 5.000000 L90.000000 35.000000 L73.000000 35.000000 Z" fill="#ffffff" stroke="#000000" stroke-width="2" /><text dominant-baseline="central" fill="#000000" font-family="monospace" font-size="24" font-weight="normal" stroke="#000000" text-anchor="middle" x="81.5" y="20.0">8</text><path d="M90.000000 5.000000 L90.000000 5.000000 L107.000000 5.000000 L107.000000 35.000000 L90.000000 35.000000 Z" fill="#ffffff" stroke="#000000" stroke-width="2" /><text dominant-baseline="central" fill="#000000" font-family="monospace" font-size="24" font-weight="normal" stroke="#000000" text-anchor="middle" x="98.5" y="20.0">7</text></svg>

# %%
import sys
sys.path.append("..")   # or path to your project root

# %%
# %m

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd()))
