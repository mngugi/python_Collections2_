# %%
n = 5

for i in range(n):
    for j in range(i+1):
        print(chr(65+j), end='')
    print()
# Out:
# A
# AB
# ABC
# ABCD
# ABCDE

# %%
n = 5

for i in range(n):
    for j in range(i+1):
        print(chr(65+i), end='')
    print()
# Out:
# A
# BB
# CCC
# DDDD
# EEEEE

# %%
n = 5

for i in range(n):
    for j in range(i+1):
        print(j+i, end='')
    print()
# Out:
# 0
# 12
# 234
# 3456
# 45678

# %%
n = 4
num = 1


for i in range(n):
    for j in range(i+1):
        print(num, end='')
        num +=1
    print()
# Out:
# 1
# 23
# 456
# 78910

# %%
n = 5

for i in range(n):
    for j in range(i+1):
        print('*', end='')
    print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
n = 5

for i in range(n):
    for j in range(n-i-1):
        print('', end='')

    for j in range(2*i+1):
        print('*', end='')
    print()
# Out:
# *
# ***
# *****
# *******
# *********

# %%
n = 5
num =65

for i in range(n):
    for j in range(i+1):
        print(chr(num), end='')
        num +=1
    print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 6
#       4 for i in range(n):
#       5     for j in range(i+1):
# ----> 6         print(chr(num=65), end='')
#       7         num +=1
#       8     print()
#
# TypeError: chr() takes no keyword arguments
