# %%
n = 5

for i in range(n):
    for j in range(i+1):
        print(chr(65+j), end='')
    print()
# Out:
# A
# AB
# ABC
# ABCD
# ABCDE

# %%
n = 5

for i in range(n):
    for j in range(i+1):
        print(chr(65+i), end='')
    print()
# Out:
# A
# BB
# CCC
# DDDD
# EEEEE

# %%
n = 5

for i in range(n):
    for j in range(i+1):
        print(j+i, end='')
    print()
# Out:
# 0
# 12
# 234
# 3456
# 45678

# %%
n = 4
num = 1


for i in range(n):
    for j in range(i+1):
        print(num, end='')
        num +=1
    print()
# Out:
# 1
# 23
# 456
# 78910

# %%
n = 5

for i in range(n):
    for j in range(i+1):
        print('*', end='')
    print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
n = 5

for i in range(n):
    for j in range(n-i-1):
        print('', end='')

    for j in range(2*i+1):
        print('*', end='')
    print()
# Out:
# *
# ***
# *****
# *******
# *********

# %%
n = 5
num =65

for i in range(n):
    for j in range(i+1):
        print(chr(num), end='')
        num +=1
    print()
# Out:
# A
# BC
# DEF
# GHIJ
# KLMNO

# %%
n = 5

for i in range(n):
    for j in range(i+1):
        if i == 0 or j == n-1 or j == 0 or j == n-1:
            print('*', end='')
        else: 
            print('', end='')
        
        print()
# Out:
# *
# *
#
# *
#
#
# *
#
#
#
# *
#
#
#
# *

# %%
n = int(input('Enter the number of rows: '))
n = 5


for i in range(n):
    for j in range(i+1):
        print('*', end='')
        num +=1
    print()
# Out:
# Enter the number of rows:  10
# *
# **
# ***
# ****
# *****
