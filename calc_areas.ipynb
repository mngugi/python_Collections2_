# %%
import Functions.ipynb

calc_rect_area(14,12)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import Functions.ipynb
#       3 calc_rect_area(14,12)
#
# ModuleNotFoundError: No module named 'Functions'
