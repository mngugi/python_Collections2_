# %%
import Functions

calc_rect_area(14,12)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import Functions
#       3 calc_rect_area(14,12)
#
# File ~/Documents/GitHub/python_Collections2_/Functions.py:22
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "22e1c390-6c8c-4b13-bf49-e32738a9d2c1",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "def calc_rect_area(lenth, width):\n",
#      11     "\n",
#      12     "    return_area = lenth * width\n",
#      13     "\n",
#      14     "    print(return_area)\n",
#      15     "    \n",
#      16     "    \n",
#      17     "    "
#      18    ]
#      19   },
#      20   {
#      21    "cell_type": "code",
# ---> 22    "execution_count": null,
#      23    "id": "04be3cdd-7c24-4b02-ba17-c27dac418dc5",
# ...
