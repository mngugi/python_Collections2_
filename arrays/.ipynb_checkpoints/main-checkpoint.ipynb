# %%
import arratyCall

arr = [0.1,0.99,0.0999,0.99999,1]

getMin = arratyCall.find_min(arr)

print(f'the minimal element is {getMin}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import arratyCall
#       3 arr = [0.1,0.99,0.0999,0.99999,1]
#       5 getMin = arratyCall.find_min(arr)
#
# File ~/Documents/GitHub/python_Collections2_/arrays/arratyCall.py:20
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "cb23c97a-bf21-478b-ab0b-e4f762f3a8de",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "def find_min():\n",
#      11     "    for i in arr:\n",
#      12     "        if i < smallest_element:\n",
#      13     "            smallest_element = i\n",
#      14     "    return smallest_element \n",
#      15     "    "
#      16    ]
#      17   },
#      18   {
#      19    "cell_type": "code",
# ---> 20    "execution_count": null,
# ...
