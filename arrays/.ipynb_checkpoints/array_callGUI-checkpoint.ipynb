# %%
import tkinter as tk
import arrayCall

root = tk.Tk()
root.title("Find Minimum Element")
root.geometry("350x350")

arr = [0.1, 0.99, 0.0999, 0.99999, 1]

def find_min_element():
    min_val = arrayCall.find_min(arr)
    result_label.config(text=f"The minimal element is: {min_val}")

# Title label
title_label = tk.Label(root, text="Minimum Value Finder", font=("Mono", 12))
title_label.pack(pady=10)

# Array display
array_label = tk.Label(root, text=f"Array: {arr}")
array_label.pack(pady=5)

# Load icon (KEEP REFERENCE)
btn_icon = tk.PhotoImage(file="check.png")

# Button
min_button = tk.Button(
    root,
    image=btn_icon,
    text=" Find Minimum",
    compound=tk.LEFT,
    command=find_min_element
)
min_button.image = btn_icon   # 🔑 critical line
min_button.pack(pady=10)

# Result label
result_label = tk.Label(root, text="", font=("Mono", 10))
result_label.pack(pady=10)

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[3], line 26
#      23 btn_icon = tk.PhotoImage(file="check.png")
#      25 # Button
# ---> 26 min_button = tk.Button(
#      27     root,
#      28     image=btn_icon,
#      29     text=" Find Minimum",
#      30     compound=tk.LEFT,
#      31     command=find_min_element
#      32 )
#      33 min_button.image = btn_icon   # 🔑 critical line
#      34 min_button.pack(pady=10)
#
# File /usr/lib/python3.13/tkinter/__init__.py:2861, in Button.__init__(self, master, cnf, **kw)
#    2842 def __init__(self, master=None, cnf={}, **kw):
#    2843     """Construct a button widget with the parent MASTER.
#    2844
#    2845     STANDARD OPTIONS
#    (...)
#    2859         overrelief, state, width
#    2860     """
# -> 2861     Widget.__init__(self, master, 'button', cnf, kw)
#
# File /usr/lib/python3.13/tkinter/__init__.py:2783, in BaseWidget.__init__(self, master, widgetName, cnf, kw, extra)
#    2781 for k, v in classes:
#    2782     del cnf[k]
# -> 2783 self.tk.call(
#    2784     (widgetName, self._w) + extra + self._options(cnf))
#    2785 for k, v in classes:
#    2786     k.configure(self, v)
#
# TclError: image "pyimage2" doesn't exist

# %%
import os
os.getcwd()
# Out:
# '/home/lamdax86/Documents/GitHub/python_Collections2_/arrays'
