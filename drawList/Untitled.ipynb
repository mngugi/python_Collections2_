# %%
from ds2.figs import drawlist

L = [0,1,6,9,8,7]
drawlist(L, 'list03')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 from ds2.figs import drawlist
#       3 L = [0,1,6,9,8,7]
# ----> 4 drawlist(L, 'list03')
#
# File ~/.venv/lib/python3.13/site-packages/ds2/figs/drawing.py:17, in drawlist(L, name)
#      15 vizL = VizList(L)
#      16 vizL.position = (5,5)
# ---> 17 with svg_plus_pdf(600, 60, figpath(name)) as canvas:
#      18     vizL.draw(canvas)
#
# File /usr/lib/python3.13/contextlib.py:148, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     146 if typ is None:
#     147     try:
# --> 148         next(self.gen)
#     149     except StopIteration:
#     150         return False
#
# File ~/.venv/lib/python3.13/site-packages/ds2viz/canvas.py:13, in svg_plus_pdf(width, height, filename, styles)
#      11 canvas = Canvas(width, height, styles)
#      12 yield canvas
# ...

# %%
import sys
sys.path.append("..")   # or path to your project root

# %%
# !pip install -e
# Out:
# Usage:
#   pip install [options] <requirement specifier> [package-index-options] ...
#   pip install [options] -r <requirements file> [package-index-options] ...
#   pip install [options] [-e] <vcs project url> ...
#   pip install [options] [-e] <local project path> ...
#   pip install [options] <archive url/path> ...
#
# -e option requires 1 argument

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd()))
